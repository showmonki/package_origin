# %% [markdown]
# # IMF
# - 区分实际销售地
# - 现有issue： 原装进口，国内包装
# - 港版但关键词有新西兰：Aptamil爱他美中国香港版活性全新白金版婴儿配方牛奶粉2段新西兰
# > https://detail.tmall.hk/hk/item.htm?spm=a220m.1000858.1000725.31.b5756cf8oZ9WhG&id=584044012180&areaId=310100&user_id=2200581879164&cat_id=2&is_b=1&rn=13c1c8bd51bc4b28a7b2179819b5f0d7#
# - 原产国：新西兰， 启运国：澳大利亚
#
# |语言|版本|
# |------------------|----------------------|
# | 中文 | 国产 |
# | 英文 | 澳洲，新西兰版|
# | 德语 | 德国|
#
#
# ## 出发点
# * 识别图片包装语言，先提取一层信息

# %%
from PIL import Image

# %%
img_path = r'G:\My Drive\ECOM\New project\Image\Package language\Aptamil 国产.png'
im = Image.open(img_path)
display(im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=823x762 at 0x2CEDBDE84E0>

# %%
img_path = r'G:\My Drive\ECOM\New project\Image\Package language\Aptamil 港版.png'
im = Image.open(img_path)
display(im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1201x829 at 0x2CEDBDF09E8>
